# %% [markdown]
# # Imports

# %%
import os
import sys
from collections import defaultdict
from collections import Counter
import shutil
import numpy as np
import re
from symusic import Score, Tempo
import pickle

# Add the absolute path to the root directory
script_dir = os.path.abspath('.')
root_dir = os.path.dirname(script_dir)
sys.path.insert(0, root_dir)

from data import *

# %% [markdown]
# # Globals

# %%
dataset_root = os.path.join(script_dir, "serialized")
os.makedirs(dataset_root, exist_ok=True)

def get_midi_files(dataset_root: str) -> dict:
    '''
    Count and get the number of MIDI files in the dataset.
    Return a dictionary with the following structure:
    {
        'subdir': {
            'files': list of MIDI files,
            'count': number of MIDI files
        }
    }
    '''
    groove_extensions = ['.mid', '.MID', '.Mid']

    midi_files = {}
    print("\nMIDI file counts in each first-level subdirectory of root (recursive):")
    root_subdirs = [d for d in os.listdir(dataset_root) if os.path.isdir(os.path.join(dataset_root, d))]
    for subdir in root_subdirs:
        subdir_path = os.path.join(dataset_root, subdir)
        midi_count = 0
        files_list = []
        for root, dirs, files in os.walk(subdir_path):
            midi_files_in_dir = [os.path.join(root, f) for f in files if any(f.endswith(ext) for ext in groove_extensions)]
            midi_count += len(midi_files_in_dir)
            files_list.extend(midi_files_in_dir)
            assert len(files_list) == midi_count
            midi_files[subdir] = {
                'files': files_list,
                'count': midi_count
            }

    total_count = sum(data['count'] for data in midi_files.values())
    sorted_midi_files = dict(sorted(midi_files.items(), key=lambda x: x[1]['count'], reverse=True))
    print(f"Total MIDI files: {total_count}")

    for subdir, data in sorted_midi_files.items():
        print(f"{subdir}: {data['count']} MIDI files")

    return sorted_midi_files

# %% [markdown]
# # MIDIMAN Processing

# %% [markdown]
# ## Process 50s Drummer Autumn Dataset

# %% [markdown]
# ### Count files in each subdirectory

# %%
midi_dir = os.path.join(script_dir, 'raw', '50s Drummer MIDI files')
midi_files = get_midi_files(midi_dir)
# Out:
# MIDI file counts in each first-level subdirectory of root (recursive):
# Total MIDI files: 800
# Indie: 200 MIDI files
# Pop: 100 MIDI files
# Blues: 100 MIDI files
# Rock: 100 MIDI files
# Soul: 100 MIDI files
# Country: 100 MIDI files
# Jazz: 100 MIDI files

# %% [markdown]
# ### Create dataset

# %%
dataset = []
ID = 0
name = "50sAutumn"

for subdir, data in midi_files.items():
    if "avg_dropped_notes" not in data:
        data['avg_dropped_notes'] = 0

    num_dropped_notes = 0
    dropped_set = set()
    for file in data['files']:
        try:
            feature = DrumMIDIFeature.from_file(file, drum_map=AUTUMN_50S_REDUCED_DRUM_MAP)
            num_dropped_notes += feature.num_dropped_notes
            dropped_set.update(feature.dropped_set)        
        except Exception as e:
            try:    
                # Single tempo fix: extract tempo from file name
                try:
                    tempo = int(re.search(r'(\d+)\s*BPM', file).group(1))
                except Exception as e1: # If tempo is not in file name, use first tempo from score
                    tempo = score.tempos[0].qpm
                score = Score.from_file(file)
                score.tracks[0].is_drum = True
                score.tempos = [Tempo(time=0, qpm=tempo)]
                # Multiple tracks fix: merge all tracks into one
                if len(score.tracks) > 1:
                    note_list_copy = score.tracks[0].notes.copy()
                    note_list_copy.extend(score.tracks[1].notes)
                    note_list_copy.sort(key=None, reverse=False, inplace=True)
                    score.tracks[0].notes = note_list_copy
                    score.tracks.pop(1)
                feature = DrumMIDIFeature.from_score(score, drum_map=AUTUMN_50S_REDUCED_DRUM_MAP)
                num_dropped_notes += feature.num_dropped_notes
                dropped_set.update(feature.dropped_set)
            except Exception as e: # If error, print score info and exit
                print(f"Error processing file: {file}")
                print(e)
                for track in score.tracks:
                    print(f"start: {track.start()}, end: {track.end()}, is_drum: {track.is_drum}")


        style = subdir.lower()
        time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
        midi_bytes = feature.score.dumps_midi()
        # Keep everything after the subdir
        parts = file.split(os.sep)
        metadata = parts[parts.index(subdir) + 1:]
        metadata[-1] = metadata[-1].split('.')[0]
        type = "fill" if "fill" in file.lower() else "beat"

        dataset.append({
                    'id': f"{name}_{ID}",
                    'map': 'autumn_50s',
                    'style': style,
                    'time_signature': time_signature,
                    'type': type,
                    'metadata': metadata,
                    'midi_bytes': midi_bytes
                })
        ID += 1
    data['avg_dropped_notes'] = num_dropped_notes / len(data['files'])
    print(f"{subdir}: avg_dropped_notes: {data['avg_dropped_notes']}")
    print(f"dropped_set: {dropped_set}")

out_name = os.path.join(dataset_root, f"{name}.pkl")
with open(out_name, "wb") as f:
    pickle.dump(dataset, f)
print(f"Saved {len(dataset)} entries to {out_name}")
# Out:
# Indie: avg_dropped_notes: 0.0
# dropped_set: set()
# Pop: avg_dropped_notes: 0.0
# dropped_set: set()
# Blues: avg_dropped_notes: 0.0
# dropped_set: set()
# Rock: avg_dropped_notes: 0.0
# dropped_set: set()
# Soul: avg_dropped_notes: 0.0
# dropped_set: set()
# Country: avg_dropped_notes: 0.0
# dropped_set: set()
# Jazz: avg_dropped_notes: 0.0
# dropped_set: set()
# Saved 800 entries to /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/serialized/50sAutumn.pkl

# %% [markdown]
# ### Test 5 random samples

# %%
with open(out_name, "rb") as f:
    dataset = pickle.load(f)

for i in range(5):
    random_index = np.random.randint(0, len(dataset))
    datapoint = dataset[random_index]
    print(f"style: {datapoint['style']}, time_signature: {datapoint['time_signature']}, type: {datapoint['type']}")
    feature = DrumMIDIFeature(datapoint['midi_bytes'], drum_map=GM_REDUCED_DRUM_MAP)
    feature.play()
    print(f"dropped_notes: {feature.num_dropped_notes}")

# %% [markdown]
# ## Process 60s Drummer Early Dataset

# %% [markdown]
# ### Count files in each subdirectory

# %%
midi_dir = os.path.join(script_dir, 'raw', '60s Drummer MIDI files')
midi_files = get_midi_files(midi_dir)
# Out:
# MIDI file counts in each first-level subdirectory of root (recursive):
# Total MIDI files: 1000
# Rock: 600 MIDI files
# Soul: 200 MIDI files
# Jazz: 200 MIDI files

# %% [markdown]
# ### Create dataset

# %%
dataset = []
ID = 0
name = "60sEarly"

for subdir, data in midi_files.items():
    if "avg_dropped_notes" not in data:
        data['avg_dropped_notes'] = 0

    num_dropped_notes = 0
    dropped_set = set()
    for file in data['files']:
        try:
            feature = DrumMIDIFeature.from_file(file, drum_map=EARLY_60S_REDUCED_DRUM_MAP)
            num_dropped_notes += feature.num_dropped_notes
            dropped_set.update(feature.dropped_set)        
        except Exception as e:
            try:    
                # Single tempo fix: extract tempo from file name
                try:
                    tempo = int(re.search(r'(\d+)\s*BPM', file).group(1))
                except Exception as e1: # If tempo is not in file name, use first tempo from score
                    tempo = score.tempos[0].qpm
                score = Score.from_file(file)
                score.tracks[0].is_drum = True
                score.tempos = [Tempo(time=0, qpm=tempo)]
                # Multiple tracks fix: merge all tracks into one
                if len(score.tracks) > 1:
                    note_list_copy = score.tracks[0].notes.copy()
                    note_list_copy.extend(score.tracks[1].notes)
                    note_list_copy.sort(key=None, reverse=False, inplace=True)
                    score.tracks[0].notes = note_list_copy
                    score.tracks.pop(1)
                feature = DrumMIDIFeature.from_score(score, drum_map=EARLY_60S_REDUCED_DRUM_MAP)
                num_dropped_notes += feature.num_dropped_notes
                dropped_set.update(feature.dropped_set)
            except Exception as e: # If error, print score info and exit
                print(f"Error processing file: {file}")
                print(e)
                for track in score.tracks:
                    print(f"start: {track.start()}, end: {track.end()}, is_drum: {track.is_drum}")


        style = subdir.lower()
        time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
        midi_bytes = feature.score.dumps_midi()
        # Keep everything after the subdir
        parts = file.split(os.sep)
        metadata = parts[parts.index(subdir) + 1:]
        metadata[-1] = metadata[-1].split('.')[0]
        type = "fill" if "fill" in file.lower() else "beat"

        dataset.append({
                    'id': f"{name}_{ID}",
                    'map': 'early_60s',
                    'style': style,
                    'time_signature': time_signature,
                    'type': type,
                    'metadata': metadata,
                    'midi_bytes': midi_bytes
                })
        ID += 1
    data['avg_dropped_notes'] = num_dropped_notes / len(data['files'])
    print(f"{subdir}: avg_dropped_notes: {data['avg_dropped_notes']}")
    print(f"dropped_set: {dropped_set}")

out_name = os.path.join(dataset_root, f"{name}.pkl")
with open(out_name, "wb") as f:
    pickle.dump(dataset, f)
print(f"Saved {len(dataset)} entries to {out_name}")
# Out:
# Rock: avg_dropped_notes: 0.0
# dropped_set: set()
# Soul: avg_dropped_notes: 0.0
# dropped_set: set()
# Jazz: avg_dropped_notes: 0.0
# dropped_set: set()
# Saved 1000 entries to /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/serialized/60sEarly.pkl

# %% [markdown]
# ### Test 5 random samples

# %%
with open(out_name, "rb") as f:
    dataset = pickle.load(f)

for i in range(5):
    random_index = np.random.randint(0, len(dataset))
    datapoint = dataset[random_index]
    print(f"style: {datapoint['style']}, time_signature: {datapoint['time_signature']}, type: {datapoint['type']}")
    feature = DrumMIDIFeature(datapoint['midi_bytes'], drum_map=GM_REDUCED_DRUM_MAP)
    feature.play()
    print(f"dropped_notes: {feature.num_dropped_notes}")

# %% [markdown]
# ## Process 70s Drummer Open Dataset

# %% [markdown]
# ### Count files in each subdirectory

# %%
midi_dir = os.path.join(script_dir, 'raw', '70s Drummer MIDI files')
midi_files = get_midi_files(midi_dir)
# Out:
# MIDI file counts in each first-level subdirectory of root (recursive):
# Total MIDI files: 1000
# Rock: 400 MIDI files
# Funk: 300 MIDI files
# Pop: 200 MIDI files
# Reggae: 100 MIDI files

# %% [markdown]
# ### Create dataset

# %%
dataset = []
ID = 0
name = "70sOpen"

for subdir, data in midi_files.items():
    if "avg_dropped_notes" not in data:
        data['avg_dropped_notes'] = 0

    num_dropped_notes = 0
    dropped_set = set()
    for file in data['files']:
        try:
            feature = DrumMIDIFeature.from_file(file, drum_map=OPEN_70S_REDUCED_DRUM_MAP)
            num_dropped_notes += feature.num_dropped_notes
            dropped_set.update(feature.dropped_set)        
        except Exception as e:
            try:    
                # Single tempo fix: extract tempo from file name
                try:
                    tempo = int(re.search(r'(\d+)\s*BPM', file).group(1))
                except Exception as e1: # If tempo is not in file name, use first tempo from score
                    tempo = score.tempos[0].qpm
                score = Score.from_file(file)
                score.tracks[0].is_drum = True
                score.tempos = [Tempo(time=0, qpm=tempo)]
                # Multiple tracks fix: merge all tracks into one
                if len(score.tracks) > 1:
                    note_list_copy = score.tracks[0].notes.copy()
                    note_list_copy.extend(score.tracks[1].notes)
                    note_list_copy.sort(key=None, reverse=False, inplace=True)
                    score.tracks[0].notes = note_list_copy
                    score.tracks.pop(1)
                feature = DrumMIDIFeature.from_score(score, drum_map=OPEN_70S_REDUCED_DRUM_MAP)
                num_dropped_notes += feature.num_dropped_notes
                dropped_set.update(feature.dropped_set)
            except Exception as e: # If error, print score info and exit
                print(f"Error processing file: {file}")
                print(e)
                for track in score.tracks:
                    print(f"start: {track.start()}, end: {track.end()}, is_drum: {track.is_drum}")


        style = subdir.lower()
        time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
        midi_bytes = feature.score.dumps_midi()
        parts = file.split(os.sep)
        metadata = parts[parts.index(subdir) + 1:]
        metadata[-1] = metadata[-1].split('.')[0]
        type = "fill" if "fill" in file.lower() else "beat"

        dataset.append({
                    'id': f"{name}_{ID}",
                    'map': 'open_70s',
                    'style': style,
                    'time_signature': time_signature,
                    'type': type,
                    'metadata': metadata,
                    'midi_bytes': midi_bytes
                })
        ID += 1
    data['avg_dropped_notes'] = num_dropped_notes / len(data['files'])
    print(f"{subdir}: avg_dropped_notes: {data['avg_dropped_notes']}")
    print(f"dropped_set: {dropped_set}")

out_name = os.path.join(dataset_root, f"{name}.pkl")
with open(out_name, "wb") as f:
    pickle.dump(dataset, f)
print(f"Saved {len(dataset)} entries to {out_name}")
# Out:
# Rock: avg_dropped_notes: 0.005
# dropped_set: {106}
# Funk: avg_dropped_notes: 0.0
# dropped_set: set()
# Pop: avg_dropped_notes: 0.0
# dropped_set: set()
# Reggae: avg_dropped_notes: 0.0
# dropped_set: set()
# Saved 1000 entries to /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/serialized/70sOpen.pkl

# %% [markdown]
# ### Test 5 random samples

# %%
with open(out_name, "rb") as f:
    dataset = pickle.load(f)

for i in range(5):
    random_index = np.random.randint(0, len(dataset))
    datapoint = dataset[random_index]
    print(f"style: {datapoint['style']}, time_signature: {datapoint['time_signature']}, type: {datapoint['type']}")
    feature = DrumMIDIFeature(datapoint['midi_bytes'], drum_map=GM_REDUCED_DRUM_MAP)
    feature.play()
    print(f"dropped_notes: {feature.num_dropped_notes}")

# %% [markdown]
# ## Process 80s Drummer Black Dataset

# %% [markdown]
# ### Count files in each subdirectory

# %%
midi_dir = os.path.join(script_dir, 'raw', '80s Drummer MIDI files')
midi_files = get_midi_files(midi_dir)
# Out:
# MIDI file counts in each first-level subdirectory of root (recursive):
# Total MIDI files: 1000
# Pop: 300 MIDI files
# Metal: 300 MIDI files
# Indie: 200 MIDI files
# Punk: 200 MIDI files

# %% [markdown]
# ### Create dataset

# %%
dataset = []
ID = 0
name = "80sBlack"

for subdir, data in midi_files.items():
    if "avg_dropped_notes" not in data:
        data['avg_dropped_notes'] = 0

    num_dropped_notes = 0
    dropped_set = set()
    for file in data['files']:
        try:
            feature = DrumMIDIFeature.from_file(file, drum_map=BLACK_80S_REDUCED_DRUM_MAP)
            num_dropped_notes += feature.num_dropped_notes
            dropped_set.update(feature.dropped_set)        
        except Exception as e:
            try:    
                # Single tempo fix: extract tempo from file name
                try:
                    tempo = int(re.search(r'(\d+)\s*BPM', file).group(1))
                except Exception as e1: # If tempo is not in file name, use first tempo from score
                    tempo = score.tempos[0].qpm
                score = Score.from_file(file)
                score.tracks[0].is_drum = True
                score.tempos = [Tempo(time=0, qpm=tempo)]
                # Multiple tracks fix: merge all tracks into one
                if len(score.tracks) > 1:
                    note_list_copy = score.tracks[0].notes.copy()
                    note_list_copy.extend(score.tracks[1].notes)
                    note_list_copy.sort(key=None, reverse=False, inplace=True)
                    score.tracks[0].notes = note_list_copy
                    score.tracks.pop(1)
                feature = DrumMIDIFeature.from_score(score, drum_map=BLACK_80S_REDUCED_DRUM_MAP)
                num_dropped_notes += feature.num_dropped_notes
                dropped_set.update(feature.dropped_set)
            except Exception as e: # If error, print score info and exit
                print(f"Error processing file: {file}")
                print(e)
                for track in score.tracks:
                    print(f"start: {track.start()}, end: {track.end()}, is_drum: {track.is_drum}")


        style = subdir.lower()
        time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
        midi_bytes = feature.score.dumps_midi()
        # Keep everything after the subdir
        parts = file.split(os.sep)
        metadata = parts[parts.index(subdir) + 1:]
        metadata[-1] = metadata[-1].split('.')[0]
        type = "fill" if "fill" in file.lower() else "beat"

        dataset.append({
                    'id': ID,
                    'map': 'black_80s',
                    'style': style,
                    'time_signature': time_signature,
                    'type': type,
                    'metadata': metadata,
                    'midi_bytes': midi_bytes
                })
        ID += 1
    data['avg_dropped_notes'] = num_dropped_notes / len(data['files'])
    print(f"{subdir}: avg_dropped_notes: {data['avg_dropped_notes']}")
    print(f"dropped_set: {dropped_set}")

out_name = os.path.join(dataset_root, f"{name}.pkl")
with open(out_name, "wb") as f:
    pickle.dump(dataset, f)
print(f"Saved {len(dataset)} entries to {out_name}")
# Out:
# Pop: avg_dropped_notes: 0.0
# dropped_set: set()
# Metal: avg_dropped_notes: 0.0
# dropped_set: set()
# Indie: avg_dropped_notes: 0.0
# dropped_set: set()
# Punk: avg_dropped_notes: 0.0
# dropped_set: set()
# Saved 1000 entries to /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/serialized/80sBlack.pkl

# %% [markdown]
# ### Test 5 random samples

# %%
with open(out_name, "rb") as f:
    dataset = pickle.load(f)

for i in range(5):
    random_index = np.random.randint(0, len(dataset))
    datapoint = dataset[random_index]
    print(f"style: {datapoint['style']}, time_signature: {datapoint['time_signature']}, type: {datapoint['type']}")
    feature = DrumMIDIFeature(datapoint['midi_bytes'], drum_map=GM_REDUCED_DRUM_MAP)
    feature.play()
    print(f"dropped_notes: {feature.num_dropped_notes}")

# %% [markdown]
# ## Process Studio Drummer Session Dataset

# %% [markdown]
# ### Count files in each subdirectory

# %%
midi_dir = os.path.join(script_dir, 'raw', 'Studio Drummer MIDI files')
midi_files = get_midi_files(midi_dir)
# Out:
# MIDI file counts in each first-level subdirectory of root (recursive):
# Total MIDI files: 3305
# Rock: 925 MIDI files
# Pop: 900 MIDI files
# Funk: 450 MIDI files
# Metal: 350 MIDI files
# Jazz: 350 MIDI files
# Country: 330 MIDI files

# %% [markdown]
# ### Create dataset

# %%
dataset = []
ID = 0
name = "sessionStudio"

for subdir, data in midi_files.items():
    if "avg_dropped_notes" not in data:
        data['avg_dropped_notes'] = 0

    num_dropped_notes = 0
    dropped_set = set()
    for file in data['files']:
        try:
            feature = DrumMIDIFeature.from_file(file, drum_map=SESSION_STUDIO_REDUCED_DRUM_MAP)
            num_dropped_notes += feature.num_dropped_notes
            dropped_set.update(feature.dropped_set)        
        except Exception as e:
            print(f"Error processing file: {file} - {e}")
            try:    
                # Single tempo fix: extract tempo from file name
                try:
                    tempo = int(re.search(r'(\d+)\s*BPM', file).group(1))
                except Exception as e1: # If tempo is not in file name, use first tempo from score
                    tempo = score.tempos[0].qpm
                score = Score.from_file(file)
                score.tracks[0].is_drum = True
                score.tempos = [Tempo(time=0, qpm=tempo)]
                # Multiple tracks fix: merge all tracks into one
                if len(score.tracks) > 1:
                    note_list_copy = score.tracks[0].notes.copy()
                    note_list_copy.extend(score.tracks[1].notes)
                    note_list_copy.sort(key=None, reverse=False, inplace=True)
                    score.tracks[0].notes = note_list_copy
                    score.tracks.pop(1)
                feature = DrumMIDIFeature.from_score(score, drum_map=SESSION_STUDIO_REDUCED_DRUM_MAP)
                num_dropped_notes += feature.num_dropped_notes
                dropped_set.update(feature.dropped_set)
            except Exception as e: # If error, print score info and exit
                print(f"Error processing file: {file} - {e}")
                print(e)
                for track in score.tracks:
                    print(f"start: {track.start()}, end: {track.end()}, is_drum: {track.is_drum}")


        style = subdir.lower()
        try:
            time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
        except Exception as e:
            print(f"Error processing file: {file} - {e}")
            from symusic import TimeSignature
            if '6-8' in file:
                time_signature = "6/8"
            elif '3-4' in file:
                time_signature = "3/4"
            else:
                time_signature = "4/4"
            time_sig_tuple = tuple(map(int, time_signature.split('/')))
            feature.score.time_signatures = [TimeSignature(time=0, numerator=time_sig_tuple[0], denominator=time_sig_tuple[1])]

        assert feature.is_valid(), f"Feature is not valid: {feature.validity_report()}"
        midi_bytes = feature.score.dumps_midi()
        # Keep everything after the subdir
        parts = file.split(os.sep)
        metadata = parts[parts.index(subdir) + 1:]
        metadata[-1] = metadata[-1].split('.')[0]
        type = "fill" if "fill" in file.lower() else "beat"

        dataset.append({
                    'id': f"{name}_{ID}",
                    'map': 'session_studio',
                    'style': style,
                    'time_signature': time_signature,
                    'type': type,
                    'metadata': metadata,
                    'midi_bytes': midi_bytes
                })
        ID += 1
    data['avg_dropped_notes'] = num_dropped_notes / len(data['files'])
    print(f"{subdir}: avg_dropped_notes: {data['avg_dropped_notes']}")
    print(f"dropped_set: {dropped_set}")

out_name = os.path.join(dataset_root, f"{name}.pkl")
with open(out_name, "wb") as f:
    pickle.dump(dataset, f)
print(f"Saved {len(dataset)} entries to {out_name}")
# Out:
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/15 16th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/11 16th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/16 16th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/18 8th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/12 16th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/03 8th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/07 16th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/19 8th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/06 16th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/01 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/02 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/13 16th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/04 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/08 16th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/20 16th Ride Multi.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/17 8th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/10 16th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/09 16th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/05 8th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/08 Groove 130BPM/14 16th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/18 Fill 110BPM/04 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/18 Fill 110BPM/03 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/18 Fill 110BPM/02 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/18 Fill 110BPM/01 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/18 Fill 110BPM/05 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/20 8th Perc Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/03 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/18 4th Hat Open Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/02 4th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/10 4th Cym Ghost.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/15 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/09 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/16 4th Hat Open Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/07 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/01 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/13 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/12 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/08 8th Hat Both Ghost.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/06 8th Hat Open Ghost.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/04 8th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/14 8th Ride Ghost.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/17 4th Hat Open Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/11 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/19 8th Hat Open Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/05 Groove 130BPM/05 8th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/17 Fill 110BPM/04 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/17 Fill 110BPM/03 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/17 Fill 110BPM/02 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/17 Fill 110BPM/01 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/17 Fill 110BPM/05 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/18 8th Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/06 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/09 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/19 8th Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/02 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/05 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/08 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/13 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/11 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/07 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/01 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/14 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/16 8th Ride Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/12 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/03 4th Hat Open Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/17 8th Ride Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/15 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/20 8th Toms Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/19 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/12 Groove 110BPM/04 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/09 8th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/06 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/10 8th Hat Open Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/05 4th Hat Open Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/02 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/08 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/07 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/01 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/18 4th Hat Open Multi.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/13 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/14 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/12 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/03 4th Hat Open Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/20 4th Hat Open Multi.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/04 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/17 4th Hat Open Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/11 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/16 8th Hat Both Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/19 4th Hat Open Multi.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/06 Groove 100BPM/15 4th Hat Closed Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/14 8th Hat Closed Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/03 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/09 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/08 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/05 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/16 8th Hat Closed Multi.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/06 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/02 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/17 4th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/19 8th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/11 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/07 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/18 8th Ride Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/01 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/13 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/12 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/15 8th Hat Open Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/10 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/20 16th Toms Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/01 Groove 140BPM/04 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/19 8th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/06 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/02 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/16 8th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/08 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/11 8th Hat Open Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/07 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/18 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/01 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/14 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/12 8th Hat Open Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/10 8th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/05 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/03 4th Hat Open Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/13 8th Hat Open Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/15 8th Ride Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/09 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/20 4th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/04 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/02 Groove 110BPM/17 8th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/20 Fill 110BPM/04 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/20 Fill 110BPM/03 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/20 Fill 110BPM/02 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/20 Fill 110BPM/01 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/20 Fill 110BPM/05 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/03 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/09 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/06 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/15 8th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/16 8th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/02 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/05 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/08 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/13 8th Ride Multi.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/11 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/20 8th Hat Closed Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/18 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/01 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/14 8th Ride Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/12 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/10 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/19 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/04 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/07 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/15 Groove 130BPM/17 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/10 8th Hat Closed Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/03 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/09 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/16 8th Ride Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/19 8th Ride Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/08 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/05 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/04 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/06 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/02 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/17 4th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/11 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/18 4th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/07 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/01 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/13 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/15 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/12 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/14 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/11 Groove 120BPM/20 4th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/09 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/06 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/19 8th Ride Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/14 4th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/18 8th Ride Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/10 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/02 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/08 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/13 4th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/11 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/07 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/12 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/01 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/05 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/03 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/17 8th Ride Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/16 8th Hat Closed Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/15 4th Hat Open Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/20 4th Cym Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/03 Groove 110BPM/04 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/14 Groove 110BPM/03 4th Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/14 Groove 110BPM/09 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/14 Groove 110BPM/06 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/14 Groove 110BPM/18 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/14 Groove 110BPM/10 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/14 Groove 110BPM/02 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/14 Groove 110BPM/08 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/14 Groove 110BPM/11 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Rock/Hard Rock/14 Groove 110BPM/07 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# ...
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/04 Groove 100BPM/04 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/04 Groove 100BPM/11 4th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/04 Groove 100BPM/19 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/04 Groove 100BPM/17 4th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/04 Groove 100BPM/06 8th Hat Closed Side.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/22 Fill 120BPM/04 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/22 Fill 120BPM/03 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/22 Fill 120BPM/02 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/22 Fill 120BPM/01 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/22 Fill 120BPM/05 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/19 Fill 100BPM/04 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/19 Fill 100BPM/03 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/19 Fill 100BPM/02 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/19 Fill 100BPM/01 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/19 Fill 100BPM/05 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/21 Fill 130BPM/04 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/21 Fill 130BPM/03 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/21 Fill 130BPM/02 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/21 Fill 130BPM/01 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/21 Fill 130BPM/05 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/24 Fill 110BPM/04 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/24 Fill 110BPM/03 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/24 Fill 110BPM/02 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/24 Fill 110BPM/01 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/24 Fill 110BPM/05 Variation.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/16 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/12 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/08 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/01 8th Hat Both Side.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/17 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/13 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/03 8th Hat Closed Side.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/20 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/11 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/05 8th Hat Closed Side.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/02 8th Hat Both Side.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/10 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/14 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/15 8th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/09 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/18 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/19 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/04 8th Hat Both Side.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/07 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/14 Groove 80BPM/06 8th Hat Closed Side.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/17 4th Hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/16 8th Toms Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/18 4th hat Open.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/10 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/02 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/14 8th Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/13 8th Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/08 4th Hat Closed Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/07 4th Hat Both Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/01 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/20 4th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/05 4th Hat Closed Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/12 8th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/09 4th Ride.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/03 4th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/19 8th Hat Closed.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/11 8th Ride Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/15 8th Toms Cym.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/06 4th Hat Closed Toms.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Error processing file: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Studio Drummer MIDI files/Country/Blues & Country/09 Groove 110BPM/04 4th Hat Both.mid - ('Invalid file! Failed checks:', ['track_is_drum', 'has_single_tempo'])
# Country: avg_dropped_notes: 0.0
# dropped_set: set()
# Saved 3305 entries to /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/serialized/sessionStudio.pkl

# %% [markdown]
# ### Test 5 random samples

# %%
with open(out_name, "rb") as f:
    dataset = pickle.load(f)

for i in range(5):
    random_index = np.random.randint(0, len(dataset))
    datapoint = dataset[random_index]
    print(f"style: {datapoint['style']}, time_signature: {datapoint['time_signature']}, type: {datapoint['type']}")
    feature = DrumMIDIFeature(datapoint['midi_bytes'], drum_map=GM_REDUCED_DRUM_MAP)
    feature.play()
    print(f"dropped_notes: {feature.num_dropped_notes}")

# %% [markdown]
# ## Process Vintage Drummer Ebony Dataset

# %% [markdown]
# ### Count files in each subdirectory

# %%
midi_dir = os.path.join(script_dir, 'raw', 'Vintage Drummer MIDI files')
midi_files = get_midi_files(midi_dir)
# Out:
# MIDI file counts in each first-level subdirectory of root (recursive):
# Total MIDI files: 750
# Jazz: 350 MIDI files
# Indie: 200 MIDI files
# Soul: 100 MIDI files
# Showtunes: 50 MIDI files
# Funk: 50 MIDI files

# %% [markdown]
# ### Create dataset

# %%
dataset = []
ID = 0
name = "ebonyVintage"

for subdir, data in midi_files.items():
    if "avg_dropped_notes" not in data:
        data['avg_dropped_notes'] = 0

    num_dropped_notes = 0
    dropped_set = set()
    for file in data['files']:
        try:
            feature = DrumMIDIFeature.from_file(file, drum_map=EBONY_VINTAGE_REDUCED_DRUM_MAP)
            num_dropped_notes += feature.num_dropped_notes
            dropped_set.update(feature.dropped_set)        
        except Exception as e:
            try:    
                # Single tempo fix: extract tempo from file name
                try:
                    tempo = int(re.search(r'(\d+)\s*BPM', file).group(1))
                except Exception as e1: # If tempo is not in file name, use first tempo from score
                    tempo = score.tempos[0].qpm
                score = Score.from_file(file)
                score.tracks[0].is_drum = True
                score.tempos = [Tempo(time=0, qpm=tempo)]
                # Multiple tracks fix: merge all tracks into one
                if len(score.tracks) > 1:
                    note_list_copy = score.tracks[0].notes.copy()
                    note_list_copy.extend(score.tracks[1].notes)
                    note_list_copy.sort(key=None, reverse=False, inplace=True)
                    score.tracks[0].notes = note_list_copy
                    score.tracks.pop(1)
                feature = DrumMIDIFeature.from_score(score, drum_map=EBONY_VINTAGE_REDUCED_DRUM_MAP)
                num_dropped_notes += feature.num_dropped_notes
                dropped_set.update(feature.dropped_set)
            except Exception as e: # If error, print score info and exit
                print(f"Error processing file: {file}")
                print(e)
                for track in score.tracks:
                    print(f"start: {track.start()}, end: {track.end()}, is_drum: {track.is_drum}")


        style = subdir.lower()
        time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
        midi_bytes = feature.score.dumps_midi()
        # Keep everything after the subdir
        parts = file.split(os.sep)
        metadata = parts[parts.index(subdir) + 1:]
        metadata[-1] = metadata[-1].split('.')[0]
        type = "fill" if "fill" in file.lower() else "beat"

        dataset.append({
                    'id': f"{name}_{ID}",
                    'map': 'ebony_vintage',
                    'style': style,
                    'time_signature': time_signature,
                    'type': type,
                    'metadata': metadata,
                    'midi_bytes': midi_bytes
                })
        ID += 1
    data['avg_dropped_notes'] = num_dropped_notes / len(data['files'])
    print(f"{subdir}: avg_dropped_notes: {data['avg_dropped_notes']}")
    print(f"dropped_set: {dropped_set}")

out_name = os.path.join(dataset_root, f"{name}.pkl")
with open(out_name, "wb") as f:
    pickle.dump(dataset, f)
print(f"Saved {len(dataset)} entries to {out_name}")
# Out:
# Jazz: avg_dropped_notes: 0.3142857142857143
# dropped_set: {74, 98}
# Indie: avg_dropped_notes: 0.0
# dropped_set: set()
# Soul: avg_dropped_notes: 0.0
# dropped_set: set()
# Showtunes: avg_dropped_notes: 0.0
# dropped_set: set()
# Funk: avg_dropped_notes: 0.0
# dropped_set: set()
# Saved 750 entries to /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/serialized/ebonyVintage.pkl

# %% [markdown]
# ### Test 5 random samples

# %%
with open(out_name, "rb") as f:
    dataset = pickle.load(f)

for i in range(5):
    random_index = np.random.randint(0, len(dataset))
    datapoint = dataset[random_index]
    print(f"style: {datapoint['style']}, time_signature: {datapoint['time_signature']}, type: {datapoint['type']}")
    feature = DrumMIDIFeature(datapoint['midi_bytes'], drum_map=GM_REDUCED_DRUM_MAP)
    feature.play()
    print(f"dropped_notes: {feature.num_dropped_notes}")

# %% [markdown]
# ## Process Modern Drummer Sparkle Dataset

# %% [markdown]
# ### Count files in each subdirectory

# %%
midi_dir = os.path.join(script_dir, 'raw', 'Modern Drummer MIDI files')
midi_files = get_midi_files(midi_dir)
# Out:
# MIDI file counts in each first-level subdirectory of root (recursive):
# Total MIDI files: 1000
# Rock: 400 MIDI files
# Metal: 200 MIDI files
# RnB: 200 MIDI files
# Electronic: 200 MIDI files

# %% [markdown]
# ### Create dataset

# %%
dataset = []
ID = 0
name = "sparkleModern"

for subdir, data in midi_files.items():
    if "avg_dropped_notes" not in data:
        data['avg_dropped_notes'] = 0

    num_dropped_notes = 0
    dropped_set = set()
    for file in data['files']:
        try:
            feature = DrumMIDIFeature.from_file(file, drum_map=SPARKLE_MODERN_REDUCED_DRUM_MAP)
            num_dropped_notes += feature.num_dropped_notes
            dropped_set.update(feature.dropped_set)        
        except Exception as e:
            try:    
                # Single tempo fix: extract tempo from file name
                try:
                    tempo = int(re.search(r'(\d+)\s*BPM', file).group(1))
                except Exception as e1: # If tempo is not in file name, use first tempo from score
                    tempo = score.tempos[0].qpm
                score = Score.from_file(file)
                score.tracks[0].is_drum = True
                score.tempos = [Tempo(time=0, qpm=tempo)]
                # Multiple tracks fix: merge all tracks into one
                if len(score.tracks) > 1:
                    note_list_copy = score.tracks[0].notes.copy()
                    note_list_copy.extend(score.tracks[1].notes)
                    note_list_copy.sort(key=None, reverse=False, inplace=True)
                    score.tracks[0].notes = note_list_copy
                    score.tracks.pop(1)
                feature = DrumMIDIFeature.from_score(score, drum_map=SPARKLE_MODERN_REDUCED_DRUM_MAP)
                num_dropped_notes += feature.num_dropped_notes
                dropped_set.update(feature.dropped_set)
            except Exception as e: # If error, print score info and exit
                print(f"Error processing file: {file}")
                print(e)
                for track in score.tracks:
                    print(f"start: {track.start()}, end: {track.end()}, is_drum: {track.is_drum}")


        style = subdir.lower()
        time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
        midi_bytes = feature.score.dumps_midi()
        # Keep everything after the subdir
        parts = file.split(os.sep)
        metadata = parts[parts.index(subdir) + 1:]
        metadata[-1] = metadata[-1].split('.')[0]
        type = "fill" if "fill" in file.lower() else "beat"

        dataset.append({
                    'id': f"{name}_{ID}",
                    'map': 'sparkle_modern',
                    'style': style,
                    'time_signature': time_signature,
                    'type': type,
                    'metadata': metadata,
                    'midi_bytes': midi_bytes
                })
        ID += 1
    data['avg_dropped_notes'] = num_dropped_notes / len(data['files'])
    print(f"{subdir}: avg_dropped_notes: {data['avg_dropped_notes']}")
    print(f"dropped_set: {dropped_set}")

out_name = os.path.join(dataset_root, f"{name}.pkl")
with open(out_name, "wb") as f:
    pickle.dump(dataset, f)
print(f"Saved {len(dataset)} entries to {out_name}")
# Out:
# Rock: avg_dropped_notes: 0.0175
# dropped_set: {99}
# Metal: avg_dropped_notes: 0.0
# dropped_set: set()
# RnB: avg_dropped_notes: 0.195
# dropped_set: {20}
# Electronic: avg_dropped_notes: 0.01
# dropped_set: {99}
# Saved 1000 entries to /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/serialized/sparkleModern.pkl

# %% [markdown]
# ### Test 5 random samples

# %%
with open(out_name, "rb") as f:
    dataset = pickle.load(f)

for i in range(5):
    random_index = np.random.randint(0, len(dataset))
    datapoint = dataset[random_index]
    print(f"style: {datapoint['style']}, time_signature: {datapoint['time_signature']}, type: {datapoint['type']}")
    feature = DrumMIDIFeature(datapoint['midi_bytes'], drum_map=GM_REDUCED_DRUM_MAP)
    feature.play()
    print(f"dropped_notes: {feature.num_dropped_notes}")

# %% [markdown]
# ## Process 2-Bar groove

# %% [markdown]
# ### Count files in each subdirectory

# %%
midi_dir = os.path.join(script_dir, 'raw', "GMD", '2bar-midionly.pkl')
with open(midi_dir, "rb") as f:
    midi_files = pickle.load(f)

midi_files = midi_files['train'] + midi_files['test'] + midi_files['validation']
print(f"2bar-midionly: {len(midi_files)} MIDI files")
# Out:
# 2bar-midionly: 22619 MIDI files

# %% [markdown]
# ### Create dataset

# %%
dataset = []
ID = 0
name = "2barGMD"

num_dropped_notes = 0
num_failures = 0
dropped_set = set()
for data in midi_files:
    style = data['style_primary']
    metadata = [data['style_secondary'], data['time_signature'], data['bpm']]
    type = data['type']
    midi_bytes = data['midi']

    try:
        feature = DrumMIDIFeature(midi_bytes, drum_map=ROLAND_TD_11_REDUCED_DRUM_MAP)
        time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
        num_dropped_notes += feature.num_dropped_notes
        dropped_set.update(feature.dropped_set)        
    except Exception as e: 
        print(f"Error: {data['id'][:10]} - {e}")
        num_failures += 1
        continue

    dataset.append({
                'id': f"{name}_{ID}",
                'map': 'roland_td_11',
                'style': style,
                'time_signature': time_signature,
                'type': type,
                'metadata': metadata,
                'midi_bytes': feature.score.dumps_midi()
            })
    
    ID += 1
    

avg_dropped_notes = num_dropped_notes / len(dataset)
print(f"{name}: avg_dropped_notes: {avg_dropped_notes}")
print(f"dropped_set: {dropped_set}")
print(f"num_failures: {num_failures}")
out_name = os.path.join(dataset_root, f"{name}.pkl")
with open(out_name, "wb") as f:
    pickle.dump(dataset, f)
print(f"Saved {len(dataset)} entries to {out_name}")
# Out:
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer5/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# ...
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# Error: drummer1/s - ('Invalid file! Failed checks:', ['has_single_track', 'track_is_drum'])
# 2barGMD: avg_dropped_notes: 0.0
# dropped_set: set()
# num_failures: 1236
# Saved 21383 entries to /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/serialized/2barGMD.pkl

# %% [markdown]
# ### Test 5 random samples

# %%
with open(out_name, "rb") as f:
    dataset = pickle.load(f)

for i in range(5):
    random_index = np.random.randint(0, len(dataset))
    datapoint = dataset[random_index]
    print(f"style: {datapoint['style']}, time_signature: {datapoint['time_signature']}, type: {datapoint['type']}")
    feature = DrumMIDIFeature(datapoint['midi_bytes'], drum_map=GM_REDUCED_DRUM_MAP)
    feature.play()
    print(f"dropped_notes: {feature.num_dropped_notes}")

# %% [markdown]
# ## Process Full groove

# %% [markdown]
# ### Count files in each subdirectory

# %%
midi_dir = os.path.join(script_dir, 'raw', "GMD", 'full-midionly.pkl')
with open(midi_dir, "rb") as f:
    midi_files = pickle.load(f)

midi_files = midi_files['train'] + midi_files['test'] + midi_files['validation']
print(f"full-midionly: {len(midi_files)} MIDI files")
# Out:
# full-midionly: 1150 MIDI files

# %% [markdown]
# ### Create dataset

# %%
dataset = []
ID = 0
name = "fullGMD"

num_dropped_notes = 0
num_failures = 0
dropped_set = set()
for data in midi_files:
    style = data['style_primary']
    metadata = [data['style_secondary'], data['time_signature'], data['bpm']]
    type = data['type']
    midi_bytes = data['midi']

    try:
        feature = DrumMIDIFeature(midi_bytes, drum_map=ROLAND_TD_11_REDUCED_DRUM_MAP)
        time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
        num_dropped_notes += feature.num_dropped_notes
        dropped_set.update(feature.dropped_set)        
    except Exception as e:
        try:    
            # Multiple tempo fix: extract first tempo from score
            score = Score.from_midi(midi_bytes)
            tempo = score.tempos[0].qpm
            score.tracks[0].is_drum = True
            score.tempos = [Tempo(time=0, qpm=tempo)]
            feature = DrumMIDIFeature.from_score(score, drum_map=ROLAND_TD_11_REDUCED_DRUM_MAP)
            time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
            num_dropped_notes += feature.num_dropped_notes
            dropped_set.update(feature.dropped_set)
        except Exception as e2:
            print(f"Error: {data['id'][:10]} - {e2}")
            num_failures += 1
            continue

    dataset.append({
                'id': f"{name}_{ID}",
                'map': 'roland_td_11',
                'style': style,
                'time_signature': time_signature,
                'type': type,
                'metadata': metadata,
                'midi_bytes': feature.score.dumps_midi()
            })
    
    ID += 1
    

avg_dropped_notes = num_dropped_notes / len(dataset)
print(f"{name}: avg_dropped_notes: {avg_dropped_notes}")
print(f"dropped_set: {dropped_set}")
print(f"num_failures: {num_failures}")
out_name = os.path.join(dataset_root, f"{name}.pkl")
with open(out_name, "wb") as f:
    pickle.dump(dataset, f)
print(f"Saved {len(dataset)} entries to {out_name}")
# Out:
# Error: Invalid file!
# Time signatures: [TimeSignature(0, 4, 4, 'Tick'), TimeSignature(0, 4, 4, 'Tick')]
# Tempos: [Tempo(0, 85.00004250002125, 705882, 'Tick'), Tempo(0, 85.00004250002125, 705882, 'Tick')]
# Error: Invalid file!
# Time signatures: [TimeSignature(0, 4, 4, 'Tick')]
# Tempos: [Tempo(0, 109.99990833340972, 545455, 'Tick'), Tempo(0, 109.99990833340972, 545455, 'Tick')]
# fullGMD: avg_dropped_notes: 0.0
# dropped_set: set()
# num_failures: 0
# Saved 1150 entries to /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/serialized/fullGMD.pkl

# %% [markdown]
# ### Test 5 random samples

# %%
with open(out_name, "rb") as f:
    dataset = pickle.load(f)

for i in range(5):
    random_index = np.random.randint(0, len(dataset))
    datapoint = dataset[random_index]
    print(f"style: {datapoint['style']}, time_signature: {datapoint['time_signature']}, type: {datapoint['type']}")
    feature = DrumMIDIFeature(datapoint['midi_bytes'], drum_map=GM_REDUCED_DRUM_MAP)
    feature.play()
    print(f"dropped_notes: {feature.num_dropped_notes}")
# Out:
# style: gospel, time_signature: 4/4, type: fill
# dropped_notes: 0
# style: rock, time_signature: 4/4, type: beat
# dropped_notes: 0
# style: rock, time_signature: 4/4, type: fill
# dropped_notes: 0
# style: country, time_signature: 4/4, type: fill
# dropped_notes: 0
# style: rock, time_signature: 4/4, type: beat
# dropped_notes: 0

# %% [markdown]
# ## Process Toontrack Drum MIDI Dataset

# %% [markdown]
# ### Count files in each subdirectory

# %%
midi_dir = os.path.join(script_dir, 'raw', 'Toontrack Drums MIDI Files')
midi_files = get_midi_files(midi_dir)
# Out:
# MIDI file counts in each first-level subdirectory of root (recursive):
# Total MIDI files: 161678
# Metal: 41060 MIDI files
# Rock: 32254 MIDI files
# Unknown: 28745 MIDI files
# Latin: 9998 MIDI files
# Jazz: 7884 MIDI files
# Blues: 6517 MIDI files
# Fusion: 5088 MIDI files
# Progressive: 4981 MIDI files
# Country: 4343 MIDI files
# Pop: 4167 MIDI files
# Electronic: 3157 MIDI files
# RnB: 2731 MIDI files
# Punk: 2553 MIDI files
# Funk: 1863 MIDI files
# Reggae: 1675 MIDI files
# Soul: 1274 MIDI files
# Gospel: 624 MIDI files
# HipHop: 594 MIDI files
# Disco: 583 MIDI files
# IndieFolk: 540 MIDI files
# Americana: 411 MIDI files
# Indie: 375 MIDI files
# Grindcore: 211 MIDI files
# Djent: 32 MIDI files
# Afrobeat: 18 MIDI files

# %% [markdown]
# ### Create dataset

# %%
dataset = []
ID = 0
name = "toontrack"

for subdir, data in midi_files.items():
    if "avg_dropped_notes" not in data:
        data['avg_dropped_notes'] = 0

    num_dropped_notes = 0
    num_failures = 0
    dropped_set = set()
    for file in data['files']:
        try:
            feature = DrumMIDIFeature.from_file(file, drum_map=GM_EXTENDED_REDUCED_DRUM_MAP)
            num_dropped_notes += feature.num_dropped_notes
            dropped_set.update(feature.dropped_set)        
        except Exception as e1: 
            try:  
                # Single tempo fix: extract tempo from file name
                score = Score.from_file(file)
                tempo = score.tempos[0].qpm
                score.tracks[0].is_drum = True
                score.tempos = [Tempo(time=0, qpm=tempo)]
                # Multiple tracks fix: merge all tracks into one
                if len(score.tracks) > 1:
                    note_list_copy = score.tracks[0].notes.copy()
                    for i, track in enumerate(score.tracks):
                        if i == 0:
                            continue
                        note_list_copy.extend(track.notes)
                    note_list_copy.sort(key=None, reverse=False, inplace=True)
                    score.tracks[0].notes = note_list_copy
                    while len(score.tracks) > 1:
                        score.tracks.pop()

                feature = DrumMIDIFeature.from_score(score, drum_map=GM_EXTENDED_REDUCED_DRUM_MAP)
                num_dropped_notes += feature.num_dropped_notes
                dropped_set.update(feature.dropped_set)
            except Exception as e2:
                print(f"Error: {file} - {e1}")
                print(f"Error: {file} - {e2}")
                num_failures += 1
                continue

        style = subdir.lower()
        try:
            time_signature = f"{feature.score.time_signatures[0].numerator}/{feature.score.time_signatures[0].denominator}"
        except Exception as e:
            print(f"Skipping {file} due to missing or invalid time signature: {e}")
            num_failures += 1
            continue
        assert feature.is_valid(), f"Feature is not valid: {feature.validity_report()}"
        # Keep everything after the subdir
        parts = file.split(os.sep)
        metadata = parts[parts.index(subdir) + 1:]
        metadata[-1] = metadata[-1].split('.')[0]
        type = "fill" if "fill" in file.lower() else "beat"

        dataset.append({
                    'id': f"{name}_{ID}",
                    'map': 'gm_extended',
                    'style': style,
                    'time_signature': time_signature,
                    'type': type,
                    'metadata': metadata,
                    'midi_bytes': feature.score.dumps_midi()
                })
        ID += 1
    data['avg_dropped_notes'] = num_dropped_notes / len(data['files'])
    print(f"{subdir}: avg_dropped_notes: {data['avg_dropped_notes']}")
    print(f"dropped_set: {dropped_set}")
    print(f"num_failures: {num_failures}")

out_name = os.path.join(dataset_root, f"{name}.pkl")
with open(out_name, "wb") as f:
    pickle.dump(dataset, f)
print(f"Saved {len(dataset)} entries to {out_name}")
# Out:
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat18.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat18.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat10.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat10.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat11.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat11.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat9.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat9.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/178bpmStupifiedBeat6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie9.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie9.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat9.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat9.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/202bpmDivineBeat1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie10.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie10.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/204bpmBallsyTongue1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/190bpmEddyDasBeat8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/172bpmBaggyBeat5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat17.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat17.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat16.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat16.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat14.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat14.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat15.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat15.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat11.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat11.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat10.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat10.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/165bpmFreakyBeat8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump9.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump9.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat12.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat12.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/176bpmAloneBeat1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/174bpmNukie1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/156bpmBlindPump8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat13.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat13.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/NU_METAL_ESSENTIALS/Beats/161bpmAliveBeat1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/183bpm4-4TripletUpbeat8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/183bpm4-4TripletUpbeat8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/111bpm8-4PhilosophicalBreak10.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/111bpm8-4PhilosophicalBreak10.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/183bpm4-4TripletUpbeat9.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/183bpm4-4TripletUpbeat9.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/187bpm3-4HomicideMachineBeat8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/187bpm3-4HomicideMachineBeat8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/178bpm4-4DoubleDoubleFun2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/157bpm4-4OpenCloseBeat6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/154bpm7-4NoToleranceBeat3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/187bpm3-4HomicideMachineBeat9.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/187bpm3-4HomicideMachineBeat9.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/113bpm6-4MoraleCrusherBeat1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/113bpm6-4MoraleCrusherBeat1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/107bpm6-4SymbolismBeat6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/107bpm6-4SymbolismBeat6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/120bpm3-4AlteringtheBeat8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/120bpm3-4AlteringtheBeat8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/183bpm4-4TripletUpbeat13.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/183bpm4-4TripletUpbeat13.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/128bpm4-4ChuckDiscoBeat14.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/128bpm4-4ChuckDiscoBeat14.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/111bpm8-4PhilosophicalBreak9.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/111bpm8-4PhilosophicalBreak9.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/111bpm8-4PhilosophicalBreak8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/111bpm8-4PhilosophicalBreak8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/128bpm4-4ChuckDiscoBeat15.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Metal/PROGRESSIVE_DEATH_METAL/Beats/128bpm4-4ChuckDiscoBeat15.mid - pyvec::index out of range: 0
# ...
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill33.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill32.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill32.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill26.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill26.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill2.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill22.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill22.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill36.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill36.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill37.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill37.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill23.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill23.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill35.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill35.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill21.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill21.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill20.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill20.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill34.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Grindcore/Fills/Fill34.mid - pyvec::index out of range: 0
# Grindcore: avg_dropped_notes: 0.0
# dropped_set: set()
# num_failures: 211
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove9.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove9.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove8.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove8.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove18.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove18.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove24.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove24.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove30.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove30.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove31.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove31.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove25.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove25.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove19.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove19.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove27.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove27.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove26.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove26.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove32.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove32.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove22.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove22.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove23.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove23.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove21.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove21.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove20.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove20.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove11.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove11.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove10.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove10.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove12.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove12.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove13.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove13.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove17.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove17.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove16.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove16.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove14.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove14.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove28.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove28.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove29.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove29.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove15.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove15.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove6.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove6.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove7.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove7.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove5.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove5.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove4.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove4.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove1.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove1.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove3.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove3.mid - pyvec::index out of range: 0
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove2.mid - ('Invalid file! Failed checks:', ['has_single_tempo'])
# Error: /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/raw/Toontrack Drums MIDI Files/Djent/Grooves/SickGroove2.mid - pyvec::index out of range: 0
# Djent: avg_dropped_notes: 0.0
# dropped_set: set()
# num_failures: 32
# Afrobeat: avg_dropped_notes: 0.0
# dropped_set: set()
# num_failures: 0
# Saved 156571 entries to /Users/puruboii/Desktop/Github-Local/drum-genie/dataset/serialized/toontrack.pkl

# %% [markdown]
# ### Test 5 random samples

# %%
with open(out_name, "rb") as f:
    dataset = pickle.load(f)

for i in range(5):
    random_index = np.random.randint(0, len(dataset))
    datapoint = dataset[random_index]
    print(f"style: {datapoint['style']}, time_signature: {datapoint['time_signature']}, type: {datapoint['type']}")
    feature = DrumMIDIFeature(datapoint['midi_bytes'], drum_map=GM_REDUCED_DRUM_MAP)
    feature.play()
    print(f"dropped_notes: {feature.num_dropped_notes}")
